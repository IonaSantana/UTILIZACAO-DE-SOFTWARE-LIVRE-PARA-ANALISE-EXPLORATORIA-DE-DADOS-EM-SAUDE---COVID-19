# %%
# %run documentacao/2_funcoes.ipynb

# %%
df_covid = pd.read_csv('documentacao/dataset/Planilha COVID19 - Aparecida 2021_02112021.csv')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3369: DtypeWarning: Columns (2,10,15,48,49,64,65,66,67) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_covid['Evolução'].value_counts() #quantidade de registro por evolução
# Out:
# Cura/Recuperado           89747
# Óbito por COVID-19         1715
# Internado - Enfermaria      170
# Isolamento Domiciliar       120
# Internado - UTI              82
# Name: Evolução, dtype: int64

# %%
df_covid['Evolução'].unique()
# Out:
# array(['Cura/Recuperado', 'Óbito por COVID-19', 'Internado - Enfermaria',
#        'Internado - UTI ', 'Isolamento Domiciliar'], dtype=object)

# %%
grafico_barra_com_porcentagem(df_covid, 'Sexo', 'Sexo')

# %%
grafico_pizza(df_covid, 'Sexo')

# %% [markdown]
# ### Sobre os valores contidos na coluna evolução: Cura/Recuperado, Óbito por COVID-19, Internado - Enfermaria, Isolamento Domiciliar, Internado - UTI

# %%
aux = df_covid[df_covid['Evolução'] == 'Cura/Recuperado'] #para pegar apenas com os valores dessa condição, para depois filtrar por sexo
grafico_barra_com_porcentagem(aux,'Sexo',f'Evolução - Cura/Recuperado')
# Out:
# ['Feminino', 'Masculino'] [48592, 41155]

# %%
aux = df_covid[df_covid['Evolução'] == 'Óbito por COVID-19'] #para pegar apenas com os valores dessa condição, para depois filtrar por sexo
grafico_barra_com_porcentagem(aux,'Sexo','Óbito por COVID-19')
# Out:
# ['Masculino', 'Feminino'] [1011, 704]

# %%
aux = df_covid[df_covid['Evolução'] == 'Internado - Enfermaria'] #para pegar apenas com os valores dessa condição, para depois filtrar por sexo
grafico_barra_com_porcentagem(aux,'Sexo','Internado - Enfermaria')
# Out:
# ['Masculino', 'Feminino'] [94, 76]

# %%
aux = df_covid[df_covid['Evolução'] == 'Internado - UTI '] #para pegar apenas com os valores dessa condição, para depois filtrar por sexo
grafico_barra_com_porcentagem(aux,'Sexo','Internado - UTI')
# Out:
# ['Masculino', 'Feminino'] [49, 33]

# %%
aux = df_covid[df_covid['Evolução'] == 'Isolamento Domiciliar'] #para pegar apenas com os valores dessa condição, para depois filtrar por sexo
grafico_barra_com_porcentagem(aux,'Sexo',f'Isolamento Domiciliar ')
# Out:
# ['Feminino', 'Masculino'] [62, 58]

# %% [markdown]
# #### Idade do pacientes

# %% [markdown]
# Geral - Ambos sexos

# %%
# IdadeM
df_covid['Outra Faixa etária'].head()
# Out:
# 0    70 a 79 anos
# 1    40 a 49 anos
# 2    40 a 49 anos
# 3    40 a 49 anos
# 4    20 a 29 anos
# Name: Outra Faixa etária, dtype: object

# %% [markdown]
# #### Histograma
# .hist() -> mostra os dados da coluna pela frequência deles

# %%
df_covid['Outra Faixa etária'].sort_values().hist(figsize = (15,10)) #A quantidade de pessoa na faixa 40 a 49 anos, está acima de 15000 e abaixo de 2000, por exemplo.
# Out:
# <AxesSubplot:>

# %% [markdown]
# Pacientes Mulheres

# %%
df_feminino = df_covid[df_covid['Sexo'] == 'Feminino']

# %% [markdown]
# Idade

# %%
df_feminino['IdadeM'].describe()
# Out:
# count    49467.000000
# mean        37.896234
# std         16.606117
# min          0.000000
# 25%         26.000000
# 50%         37.000000
# 75%         48.000000
# max        107.000000
# Name: IdadeM, dtype: float64

# %%
df_feminino['IdadeM'].hist()
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm
from scipy.stats import norm
import pylab
# my_data = norm.rvs(size=1000)
sm.qqplot(df_feminino['IdadeM'], line='45')
pylab.show()

# %%
df_feminino['Outra Faixa etária'].sort_values().hist(figsize = (15,10)) #figsize para o tamanho desejado da imagem, que mostre os detalhes tanto da classe, quanto da frequência da mesma
# Out:
# <AxesSubplot:>

# %% [markdown]
# Pacientes Homens

# %%
df_masculino = df_covid[df_covid['Sexo'] == 'Masculino']

# %%
df_masculino['IdadeM'].describe()
# Out:
# count    42367.000000
# mean        37.641041
# std         16.786633
# min          0.000000
# 25%         26.000000
# 50%         36.000000
# 75%         48.000000
# max        105.000000
# Name: IdadeM, dtype: float64

# %%
df_masculino['IdadeM'].hist()
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm
from scipy.stats import norm
import pylab
# my_data = norm.rvs(size=1000)
sm.qqplot(df_masculino['IdadeM'], line='45')
pylab.show()

# %%
df_masculino['IdadeM'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Quantos dias ficou com covid?

# %%
df_masculino['Outra Faixa etária'].sort_values().hist(figsize = (15,10)) #sort_values para ordenar as idades
# Out:
# <AxesSubplot:>

# %%
df_covid['Raça/Cor'].describe()
# Out:
# count     91834
# unique        7
# top       Parda
# freq      48453
# Name: Raça/Cor, dtype: object

# %%
df_covid['Raça/Cor'].value_counts()
# Out:
# Parda       48453
# Branca      20122
# Ignorado    11313
# Preta        6715
# Amarela      5045
# Indigena      185
# Parda           1
# Name: Raça/Cor, dtype: int64

# %%
grafico_barra(df_covid,'Raça/Cor','Raça/Cor')

# %%
df_covid['Raça/Cor'] = df_covid['Raça/Cor'].str.strip()

# %%
df_covid['Raça/Cor'].value_counts()
# Out:
# Parda       48454
# Branca      20122
# Ignorado    11313
# Preta        6715
# Amarela      5045
# Indigena      185
# Name: Raça/Cor, dtype: int64

# %%
grafico_barra(df_covid,'Raça/Cor','Raça/Cor')
